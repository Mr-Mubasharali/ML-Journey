# %% [markdown]
# <h4>Apply Lasso regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso

# %%
x,y=make_regression(n_samples=100,n_features=1,n_informative=1,n_targets=1,noise=20,random_state=12)

# %%
plt.scatter(x,y)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=12)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
ypred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
print('Coefficient LR model',lr.coef_)
print('Intercept LR model',lr.intercept_)
print('R2 Score',r2_score(y_test,ypred))
# Out:
# Coefficient LR model [38.90176409]
# Intercept LR model -1.1445473328809888
# R2 Score 0.8741784237510961

# %% [markdown]
# <h4>Apply different alphas values(lambda)

# %%
alphas=[0,10,20,30]
plt.scatter(x,y)
plt.Figure(figsize=(12,14))
for i in alphas:
    L=Lasso(alpha=i)
    L.fit(x_train,y_train)
    plt.plot(x_test,L.predict(x_test),label=f'Alpha:{i}')
plt.legend()
plt.show
# Out:
# c:\Users\Mubashar Ali\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# <function matplotlib.pyplot.show(close=None, block=None)>
